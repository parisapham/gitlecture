# %%
import pandas as pd

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
mycolumns = ['price', 'neighbourhood_group', 'neighbourhood', 'room_type', 'minimum_nights', 'number_of_reviews']
new_df = df[mycolumns]
new_df
# Out:
#        price neighbourhood_group       neighbourhood        room_type  \
# 0        149            Brooklyn          Kensington     Private room
# 1        225           Manhattan             Midtown  Entire home/apt
# 2        150           Manhattan              Harlem     Private room
# 3         89            Brooklyn        Clinton Hill  Entire home/apt
# 4         80           Manhattan         East Harlem  Entire home/apt
# ...      ...                 ...                 ...              ...
# 48890     70            Brooklyn  Bedford-Stuyvesant     Private room
# 48891     40            Brooklyn            Bushwick     Private room
# 48892    115           Manhattan              Harlem  Entire home/apt
# 48893     55           Manhattan      Hell's Kitchen      Shared room
# 48894     90           Manhattan      Hell's Kitchen     Private room
#
#        minimum_nights  number_of_reviews
# 0                   1                  9
# 1                   1                 45
# ...

# %%
new_df.dropna()
# Out:
#        price neighbourhood_group       neighbourhood        room_type  \
# 0        149            Brooklyn          Kensington     Private room
# 1        225           Manhattan             Midtown  Entire home/apt
# 2        150           Manhattan              Harlem     Private room
# 3         89            Brooklyn        Clinton Hill  Entire home/apt
# 4         80           Manhattan         East Harlem  Entire home/apt
# ...      ...                 ...                 ...              ...
# 48890     70            Brooklyn  Bedford-Stuyvesant     Private room
# 48891     40            Brooklyn            Bushwick     Private room
# 48892    115           Manhattan              Harlem  Entire home/apt
# 48893     55           Manhattan      Hell's Kitchen      Shared room
# 48894     90           Manhattan      Hell's Kitchen     Private room
#
#        minimum_nights  number_of_reviews
# 0                   1                  9
# 1                   1                 45
# ...

# %%
newer_df = new_df['number_of_reviews'] != 0
